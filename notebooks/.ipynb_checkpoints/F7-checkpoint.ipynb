# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg
import sys
from KPE2 import *

# %%
sd_all = xr.open_dataset('/Users/paban23/Research/PhD/S-MODE/SD_ADCP_Analyses/Data/All_SDs_merged_4_50m_deep/1hz/all_SMODE_SDs_ADCP.nc').sel(trajectory=['1026','1048','1085','1087'])[["u","v"]]
# Out:
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/xarray/coding/times.py:251: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/xarray/coding/times.py:251: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(

# %%
t1,t2 = '2022-10-19-18:00','2022-10-21-06:00'

# %%
ds1 = sd_all.sel(time=slice(t1,t2)).reset_coords(['longitude', 'latitude']).isel(cell_depth=np.arange(0,48,2))

# %%
ds1_subset_5min = ds1.resample(time='3min').mean(dim='time')

# %%
ds26 = ds1.sel(trajectory ='1026')
ds48 = ds1.sel(trajectory ='1048')
ds85 = ds1.sel(trajectory ='1085')
ds87 = ds1.sel(trajectory ='1087')

# %%
ds26_5min = ds1_subset_5min.sel(trajectory ='1026')
ds48_5min = ds1_subset_5min.sel(trajectory ='1048').interp(cell_depth = ds26_5min.cell_depth)
ds85_5min = ds1_subset_5min.sel(trajectory ='1085').interp(cell_depth = ds26_5min.cell_depth)
ds87_5min = ds1_subset_5min.sel(trajectory ='1087').interp(cell_depth = ds26_5min.cell_depth)

# %%
all_ds = ['ds26','ds48','ds85','ds87']
for ds in all_ds:
    #put the cartesian coordinate into the data
    exec(ds+'_5min["x"],'+ds+'_5min["y"] = ll2xy('+ds+'_5min.longitude,'+ds+'_5min.latitude,-125.1-0.01,36.79-0.02)',globals())  # changed 36.89 to 36.79
    exec(ds+'_5min["u_uncertainty"] = '+ds+'.u.resample(time="3min").std(dim="time")/np.sqrt(180)',globals())
    exec(ds+'_5min["v_uncertainty"] = '+ds+'.v.resample(time="3min").std(dim="time")/np.sqrt(180)',globals())

# %%
ds5min_all = xr.concat([ds26_5min,ds48_5min,ds85_5min,ds87_5min],dim='trajectory')

# %%
#ds5min_all.plot.scatter(x='x',y='y')

# %%
#IOP TIMES
t1s, t1e = '2022-10-19-18:00','2022-10-20-01:15'   #'2022-10-18-19:00','2022-10-20-20:15'
t2s, t2e = '2022-10-20-01:20','2022-10-20-09:10'
t3s, t3e = '2022-10-20-09:15','2022-10-20-19:30'
# t4s, t4e = '2022-10-20-15:00','2022-10-20-19:30'
t5s, t5e = '2022-10-20-19:35','2022-10-21-06:00'

# %%
sd_all_sub_iop = xr.concat([ds5min_all.sel(time=slice(t1s,t1e)),\
                     ds5min_all.sel(time=slice(t2s,t2e)),\
                     ds5min_all.sel(time=slice(t3s,t3e)),\
                       # ds5min_all.sel(time=slice(t4s,t4e)),\
                       ds5min_all.sel(time=slice(t5s,t5e)),],dim="legs")#.isel(cell_depth=np.arange(0,48,2))

# %%
rot_ds  = rotate_coords(sd_all_sub_iop)

# %%
import matplotlib.pyplot as plt

# Number of legs
num_legs = 4

# Create subplots grid
fig, axs = plt.subplots(1, num_legs, figsize=(4 * num_legs,4 ))

for legs in range(num_legs):
    # Scatter plot for 'x' and 'y'
    rot_ds.isel(legs=legs).plot.scatter(x='x', y='y', ax=axs[legs], add_colorbar=False, label='x, y')
    
    # Scatter plot for 'x_rot' and 'y_rot'
    rot_ds.isel(legs=legs).plot.scatter(x='x_rot', y='y_rot', ax=axs[legs], add_colorbar=False, label='x_rot, y_rot')
    
    # Scatter plot for mean values
    axs[legs].scatter(rot_ds.isel(legs=legs).mean_rotated_x, rot_ds.isel(legs=legs).mean_rotated_y,  label='Mean')
    
    # Remove legend if you don't want it
    axs[legs].legend_.set_visible(False)
    
plt.tight_layout()
plt.show()
# Out:
# <__array_function__ internals>:200: UserWarning: Warning: converting a masked element to nan.
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/matplotlib/colors.py:1159: UserWarning: Warning: converting a masked element to nan.
#   data = np.asarray(value)
# <__array_function__ internals>:200: UserWarning: Warning: converting a masked element to nan.
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/matplotlib/colors.py:1159: UserWarning: Warning: converting a masked element to nan.
#   data = np.asarray(value)
# <__array_function__ internals>:200: UserWarning: Warning: converting a masked element to nan.
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/matplotlib/colors.py:1159: UserWarning: Warning: converting a masked element to nan.
#   data = np.asarray(value)
# <__array_function__ internals>:200: UserWarning: Warning: converting a masked element to nan.
# ...

# %%
bds = create_box_data(rot_ds)
# Out:
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/research/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
# ...

# %%
np.nanmean(np.sqrt(bds.sigX**2 + bds.sigY**2))

# %%
bds2 = create_box_data(rot_ds.sel(trajectory=['1048','1087']))

# %%
np.nanmean(np.sqrt(bds2.sigX**2 + bds2.sigY**2))

# %%
omega = 2*np.pi/(3600*24)+ 2*np.pi/(365*86400)
f= 2*omega*np.sin((37.4*np.pi)/180)

# %%
div, vort, strain, vort_uncert, div_uncert, strain_uncert,N = calculate_kinematic_properties(4,4,bds)

# %%
depths =  rot_ds.cell_depth.values

# %%
div = xr.DataArray(div).assign_coords({'dim_1':div.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})
vort = xr.DataArray(vort).assign_coords({'dim_1':vort.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
strain = xr.DataArray(strain).assign_coords({'dim_1':strain.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
N = xr.DataArray(N).assign_coords({'dim_1':N.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
vort_uncert = xr.DataArray(vort_uncert).assign_coords({'dim_1':vort_uncert.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})
div_uncert = xr.DataArray(div_uncert).assign_coords({'dim_1':div_uncert.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})
strain_uncert = xr.DataArray(strain_uncert).assign_coords({'dim_1':strain_uncert.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
div_2SD, vort_2SD, strain_2SD, vort_uncert_2SD, div_uncert_2SD, strain_uncert_2SD,N_2SD = calculate_kinematic_properties(2,2,bds.sel(trajectory=['1048','1087']))

# %%
div_2SD = xr.DataArray(div_2SD).assign_coords({'dim_1':div_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})
vort_2SD = xr.DataArray(vort_2SD).assign_coords({'dim_1':vort_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
strain_2SD = xr.DataArray(strain_2SD).assign_coords({'dim_1':strain_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
vort_uncert_2SD = xr.DataArray(vort_uncert_2SD).assign_coords({'dim_1':vort_uncert_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})
div_uncert_2SD = xr.DataArray(div_uncert_2SD).assign_coords({'dim_1':div_uncert_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})
strain_uncert_2SD = xr.DataArray(strain_uncert_2SD).assign_coords({'dim_1':strain_uncert_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
N_2SD = xr.DataArray(N_2SD).assign_coords({'dim_1':N_2SD.dim_1}).assign_coords({'dim_0':depths,'dim_1':rot_ds.time.values}).rename({'dim_0':'depths','dim_1': 'time'})

# %%
color1 = 'dodgerblue'
color2 = 'hotpink'
color3 = 'limegreen'

# %%
abs(div_uncert).mean()/abs(div).mean()
# Out:
# <xarray.DataArray ()>
# array(0.31833468)

# %%
abs(vort_uncert).mean()/abs(vort).mean()
# Out:
# <xarray.DataArray ()>
# array(0.28103462)

# %%
abs(strain_uncert).mean()/abs(strain).mean()
# Out:
# <xarray.DataArray ()>
# array(0.20470866)

# %%
instant_kpe_in_box_3min = xr.open_dataset('../STM codes/Data/v2_aspect_0.2_error_prop_3min_all_iteration_4pointsPerplane__updatedUncertainty_kpe_alongmeantrack_intsnataneous_10-19_to_10-21_in_box.nc')

# %%
abs(instant_kpe.div_uncert).mean()/abs(instant_kpe.div).mean()
# Out:
# <xarray.DataArray ()>
# array(1.64447104)

# %%
abs(instant_kpe.vort_uncert).mean()/abs(instant_kpe.vort).mean()
# Out:
# <xarray.DataArray ()>
# array(1.63081967)

# %%
div[0,:].sel(time=slice(t1s,t1e)).min().values, div[0,:].sel(time=slice(t1s,t1e)).max().values, \
vort[0,:].sel(time=slice(t1s,t1e)).min().values, vort[0,:].sel(time=slice(t1s,t1e)).max().values,\
strain[0,:].sel(time=slice(t1s,t1e)).min().values, strain[0,:].sel(time=slice(t1s,t1e)).max().values
# Out:
# (array(-0.89989266),
#  array(1.50696766),
#  array(-0.50142303),
#  array(2.05066813),
#  array(0.1420779),
#  array(2.03943445))

# %%
fig,ax = plt.subplots(3,1,figsize=(8,5))
t1s = t1s
t1e = t1e
div[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[0],color=color1)
#div_conv[1,1:62].plot(ax=ax[0],color=color2)
ax[0].errorbar(div[0,:].sel(time=slice(t1s,t1e)).time.values,div[0,:].sel(time=slice(t1s,t1e)).values,div_uncert[0,:].sel(time=slice(t1s,t1e)).values,fmt='.',color=color1,alpha=0.2)


instant_kpe_in_box_3min.div.sel(time=slice(t1s,t1e)).plot(ax=ax[0],color=color3)
#div_conv[1,1:62].plot(ax=ax[0],color=color2)
ax[0].errorbar(instant_kpe_in_box_3min.div.sel(time=slice(t1s,t1e)).time.values[::2],instant_kpe_in_box_3min.div.sel(time=slice(t1s,t1e)).values[::2],instant_kpe_in_box_3min.div_uncert.sel(time=slice(t1s,t1e)).values[::2],fmt='.',color=color3,alpha=0.2)
#ax[0].errorbar(div_conv[1,1:62].time.values[::2],div_conv[1,1:62].values[::2],div_conv_uncert[1,1:62].values[::2],fmt='.',color=color2,alpha=0.4)

div_2SD[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[0],color=color2)
#ax[0].errorbar(div[0,:].time.values,div[0,:].values,div_uncert[0,:].values,fmt='.',color=color1,alpha=0.1)
ax[0].errorbar(div_2SD[0,:].sel(time=slice(t1s,t1e)).time.values[::2],div_2SD[0,:].sel(time=slice(t1s,t1e)).values[::2],div_uncert_2SD[0,:].sel(time=slice(t1s,t1e)).values[::2],fmt='.',color=color2,alpha=0.2)

ax[0].legend(('4 SDs (3min)','SDs Inst. (3min)','2 SDs (3min)'),bbox_to_anchor=(1.05,1.7),borderaxespad=0., frameon=True, shadow=True)
ax[0].set_ylim(-2,2.6)
ax[0].set_ylabel(r'$\delta$/f (s$^{-1}$)',fontsize=12)
ax[0].set_xlabel('')
#ax[0].set_yticks(fontsize=10)
#ax[0].set_xticks(color='w')
ax[0].set_xticklabels([])


vort[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[1],color=color1)
#vort_conv[1,1:62].plot(ax=ax[1],x='time',color=color2)
ax[1].errorbar(vort[0,:].sel(time=slice(t1s,t1e)).time.values,vort[0,:].sel(time=slice(t1s,t1e)).values,vort_uncert[0,:].sel(time=slice(t1s,t1e)).values,fmt='.',color=color1,alpha=0.2)


instant_kpe_in_box_3min.vort.sel(time=slice(t1s,t1e)).plot(ax=ax[1],color=color3)
#vort_conv[1,1:62].plot(ax=ax[1],x='time',color=color2)
ax[1].errorbar(instant_kpe_in_box_3min.vort.sel(time=slice(t1s,t1e)).time.values[::2],instant_kpe_in_box_3min.vort.sel(time=slice(t1s,t1e)).values[::2],instant_kpe_in_box_3min.vort_uncert.sel(time=slice(t1s,t1e)).values[::2],fmt='.',color=color3,alpha=0.2)
#ax[1].errorbar(vort_conv[1,1:62].time.values[::2],vort_conv[1,1:62].values[::2],vort_conv_uncert[1,1:62].values[::2],fmt='.',color=color2,alpha=0.4)

#vort[0,:].plot(ax=ax[1],color=color1)
vort_2SD[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[1],color=color2)
#ax[1].errorbar(vort[0,:].time.values,vort[0,:].values,vort_uncert[0,:].values,fmt='.',color=color1,alpha=0.1)
ax[1].errorbar(vort_2SD[0,:].sel(time=slice(t1s,t1e)).time.values[::2],vort_2SD[0,:].sel(time=slice(t1s,t1e)).values[::2],vort_uncert_2SD[0,:].sel(time=slice(t1s,t1e)).values[::2],fmt='.',color=color2,alpha=0.2)

ax[1].set_ylim(-2,2.6)
ax[1].set_ylabel(r'$\zeta$/f (s$^{-1}$)',fontsize=12)
ax[1].set_xticklabels([])
ax[1].set_xlabel('')

strain[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[2],color=color1)
ax[2].errorbar(strain[0,:].sel(time=slice(t1s,t1e)).time.values,strain[0,:].sel(time=slice(t1s,t1e)).values,strain_uncert[0,:].sel(time=slice(t1s,t1e)).values,fmt='.',color=color1,alpha=0.2)


instant_kpe_in_box_3min.strain.sel(time=slice(t1s,t1e)).plot(ax=ax[2],color=color3)
#vort_conv[1,1:62].plot(ax=ax[1],x='time',color=color2)
ax[2].errorbar(instant_kpe_in_box_3min.strain.sel(time=slice(t1s,t1e)).time.values[::2],instant_kpe_in_box_3min.strain.sel(time=slice(t1s,t1e)).values[::2],instant_kpe_in_box_3min.strain_uncert.sel(time=slice(t1s,t1e)).values[::2],fmt='.',color=color3,alpha=0.2)


strain_2SD[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[2],color=color2)
#ax[1].errorbar(vort[0,:].time.values,vort[0,:].values,vort_uncert[0,:].values,fmt='.',color=color1,alpha=0.1)
ax[2].errorbar(strain_2SD[0,:].sel(time=slice(t1s,t1e)).time.values[::2],strain_2SD[0,:].sel(time=slice(t1s,t1e)).values[::2],strain_uncert_2SD[0,:].sel(time=slice(t1s,t1e)).values[::2],fmt='.',color=color2,alpha=0.2)
# ax2 = ax[1].twinx()

# ax2.plot(vort_2SD[0,:].time,bds2.eig,color='C1')
# ax2.set_ylabel('Eigen value(2SD)',color='C1')
ax[2].set_ylim(0,2.6)
ax[2].set_ylabel(r'$\alpha$/f (s$^{-1}$)',fontsize=12)
ax[1].set_title('')
ax[2].set_title('')
#ax[2].set_xticklabels([])
ax[2].set_xlabel('')

# ax4 = ax[3].twinx()
# N[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[3],x='time',color=color1)
# instant_kpe_in_box_3min.no_of_plane.sel(time=slice(t1s,t1e)).plot(ax=ax4,color=color3)
# N_2SD[0,:].sel(time=slice(t1s,t1e)).plot(ax=ax[3],x='time',color=color2)
# ax4.set_ylabel('no_of_planes', color=color3)
# ax4.tick_params(axis='y', labelcolor=color3)

# ax[3].set_ylabel('no of data', color=color1)
# ax[3].tick_params(axis='y', labelcolor=color1)

plt.subplots_adjust(hspace=0.5)
ax[0].set_title('Quad formation (weighted LS)')

ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

ax[2].spines['top'].set_visible(False)
ax[2].spines['right'].set_visible(False)


# ax[3].spines['top'].set_visible(False)
#ax[3].spines['right'].set_visible(False)
#plt.savefig('../Plots/KPE_error_prop_4SDs_vs_2SD_vs_instant4SD_3min_Quad_IOP1_updated_uncert_aspect_0.2.png',bbox_inches='tight',dpi=150)

# %%
counts, bin_edges = np.histogram(vort[0,:].dropna(dim='time'), bins=30, density=True)  # Adjust bins as needed
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2  # Compute bin centers

# Plot histogram as a line
plt.plot(bin_centers, counts,) #label='Histogram as Line')
plt.xlabel(r'$\zeta$/f (s$^{-1}$)',fontsize=12)
plt.ylabel('Density')
plt.title('Normalized vorticity at 6m depth')
#plt.legend()
#plt.xlim(-3,3)
plt.show()

# %%
counts, bin_edges = np.histogram(vort.dropna(dim='time'), bins=30, density=True)  # Adjust bins as needed
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2  # Compute bin centers

# Plot histogram as a line
plt.plot(bin_centers, counts,) #label='Histogram as Line')
plt.xlabel(r'$\zeta$/f (s$^{-1}$)',fontsize=12)
plt.ylabel('Probability Density')
plt.title('Normalized vorticity at 6-50m depth')
#plt.legend()
#plt.xlim(-3,3)
plt.yscale('log')
plt.show()

# %%
skewness = np.nanmean(skew(vort[0,:].dropna(dim='time')))
skewness
# Out:
# 0.8365501585362265

# %%
skewness = np.nanmean(skew(vort.dropna(dim='time')))
skewness
# Out:
# 0.16911098546468778
